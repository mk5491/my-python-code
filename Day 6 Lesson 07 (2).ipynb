# %%
import numpy as np
first_trial_cyclist = np.array([10,56,23,15,34],dtype='int64')
first_trial_cyclist
first_trial_cyclist.dtype
# Out:
# dtype('int64')

# %%
first_trial_cyclist = np.array([10,56,23,15,"34"])
first_trial_cyclist.dtype
# Out:
# dtype('<U21')

# %%
########### Lesson 07 - Pandas

# %%
import pandas as pd
# one dimensional object
Cust_age = pd.Series([23,45,26,78,45])
print(Cust_age)
# Out:
# 0    23
# 1    45
# 2    26
# 3    78
# 4    45
# dtype: int64

# %%
Cust_age + 5
# Out:
# 0    28
# 1    50
# 2    31
# 3    83
# 4    50
# dtype: int64

# %%
Cust_age = pd.Series([23,45,26,np.NaN,78,45,None])
Cust_age
Cust_age.dtype
# Out:
# dtype('float64')

# %%
# implicit coersion
Cust_age = pd.Series([23,45,26,'78',45])
print(Cust_age)
# Out:
# 0    23
# 1    45
# 2    26
# 3    78
# 4    45
# dtype: object

# %%
# explicit coersion
Cust_age = pd.Series([23,45,26,'78',45],dtype='int32')
print(Cust_age)
# Out:
# 0    23
# 1    45
# 2    26
# 3    78
# 4    45
# dtype: int32

# %%
Cust_Name = pd.Series(["John","Paul","Lisa"])
print(Cust_Name)
print(Cust_Name.dtype)
print(type(Cust_Name))
# Out:
# 0    John
# 1    Paul
# 2    Lisa
# dtype: object
# object
# <class 'pandas.core.series.Series'>

# %%
LogVect = pd.Series([True,False])
print(LogVect)
LogVect.dtype
# Out:
# 0     True
# 1    False
# dtype: bool
# dtype('bool')

# %%
Score_Maths = [78,89,"76",90,67]
Score_Maths_series = pd.Series(Score_Maths)
print(Score_Maths_series)
# Out:
# 0    78
# 1    89
# 2    76
# 3    90
# 4    67
# dtype: object

# %%
# convert to integer data type
New_Marks = Score_Maths_series.astype(int) + 5
New_Marks
# Out:
# 0    83
# 1    94
# 2    81
# 3    95
# 4    72
# dtype: int64

# %%
# convert integer to to string
New_Marks.astype(str)
# Out:
# 0    83
# 1    94
# 2    81
# 3    95
# 4    72
# dtype: object

# %%
# convert integer to bool
New_Marks.astype(bool)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
Customer_card = pd.Series([0,1,3,0,5,7,0,3,-4])
Customer_card.astype(bool)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
## customized indexing in pandas
gdp = pd.Series([5,7],index=["India","US"])
gdp
# Out:
# India    5
# US       7
# dtype: int64

# %%
gdp[0]
# Out:
# 5

# %%
gdp['India']
# Out:
# 5

# %%
gdp['US']
# Out:
# 7

# %%
# Pandas data frame
import pandas as pd
EmpRecs = pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23]})
EmpRecs
# Out:
#         Name_Emp  Age
# 0   Andy Simpson   34
# 1  John Anderson   45
# 2    Liza Brooke   23

# %%
print(type(EmpRecs))
# Out:
# pandas.core.frame.DataFrame

# %%
EmpRecs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name_Emp  3 non-null      object
#  1   Age       3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
Emp_Details= pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23],'GT_5_yrs':[True,False,False]})
Emp_Details
# Out:
#         Name_Emp  Age  GT_5_yrs
# 0   Andy Simpson   34      True
# 1  John Anderson   45     False
# 2    Liza Brooke   23     False

# %%
Emp_Details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name_Emp  3 non-null      object
#  1   Age       3 non-null      int64
#  2   GT_5_yrs  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
# create indexes for each row
Emp_Details= pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23],'GT_5_yrs':[True,False,False]},
                          index=['Andy','John','Liza'])
Emp_Details
# Out:
#            Name_Emp  Age  GT_5_yrs
# Andy   Andy Simpson   34      True
# John  John Anderson   45     False
# Liza    Liza Brooke   23     False

# %%
# slide 26 - Go through

# %%
#Scenrio 1
olympic_number_of_countries = pd.Series([203,205],index=[2011,2012])
olympic_countries_name = pd.Series(['London','India'],index=[2011,2012])
pd.DataFrame({'Country_name':olympic_countries_name,'No_of_memnbers':olympic_number_of_countries})
# Out:
#      Country_name  No_of_memnbers
# 2011       London             203
# 2012        India             205

# %%
#Scenrio 2
olympic_number_of_countries = pd.Series([203,205],index=[2011,2012])
olympic_countries_name = pd.Series(['London','India'],index=[2011,2013])
pd.DataFrame({'Country_name':olympic_countries_name,'No_of_memnbers':olympic_number_of_countries})
# Out:
#      Country_name  No_of_memnbers
# 2011       London           203.0
# 2012          NaN           205.0
# 2013        India             NaN

# %%
Emp_Details= pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23],'GT_5_yrs':[True,False,False]},index=['Andy','John','Liza'])
Emp_Details
# Out:
#            Name_Emp  Age  GT_5_yrs
# Andy   Andy Simpson   34      True
# John  John Anderson   45     False
# Liza    Liza Brooke   23     False

# %%
Emp_Details.loc['Andy',:]
# or
Emp_Details.loc['Andy']
# Out:
# Name_Emp    Andy Simpson
# Age                   34
# GT_5_yrs            True
# Name: Andy, dtype: object

# %%
# 2 records together
Emp_Details.loc[['Andy','Liza'],:]
# Out:
#           Name_Emp  Age  GT_5_yrs
# Andy  Andy Simpson   34      True
# Liza   Liza Brooke   23     False

# %%
# filtering by column name and row index names
Emp_Details.loc['Andy':'Liza',:]
# Out:
#            Name_Emp  Age  GT_5_yrs
# Andy   Andy Simpson   34      True
# John  John Anderson   45     False
# Liza    Liza Brooke   23     False

# %%
# filtering by column name and row index names
Emp_Details.loc['Andy':'Liza',['Age','Name_Emp']]
# Out:
#       Age       Name_Emp
# Andy   34   Andy Simpson
# John   45  John Anderson
# Liza   23    Liza Brooke

# %%
Emp_Details.loc[['Andy','Liza'],['Age','Name_Emp']]
# Out:
#       Age      Name_Emp
# Andy   34  Andy Simpson
# Liza   23   Liza Brooke

# %%
# iloc
Emp_Details= pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23],'GT_5_yrs':[True,False,False]},
                          index=['Andy','John','Liza'])
Emp_Details
# Out:
#            Name_Emp  Age  GT_5_yrs
# Andy   Andy Simpson   34      True
# John  John Anderson   45     False
# Liza    Liza Brooke   23     False

# %%
Emp_Details.iloc[2,:]
# Out:
# Name_Emp    Liza Brooke
# Age                  23
# GT_5_yrs          False
# Name: Liza, dtype: object

# %%
Emp_Details.iloc[[1,2],:]
# Out:
#            Name_Emp  Age  GT_5_yrs
# John  John Anderson   45     False
# Liza    Liza Brooke   23     False

# %%
Emp_Details.iloc[[1,2],[0,2]]
# Out:
#            Name_Emp  GT_5_yrs
# John  John Anderson     False
# Liza    Liza Brooke     False

# %%
Emp_Details= pd.DataFrame({'Name_Emp':['Andy Simpson','John Anderson','Liza Brooke'],'Age':[34,45,23],'GT_5_yrs':[True,False,False]})
Emp_Details
# Out:
#         Name_Emp  Age  GT_5_yrs
# 0   Andy Simpson   34      True
# 1  John Anderson   45     False
# 2    Liza Brooke   23     False

# %%
Emp_Details.loc[[0,2],:]
# Out:
#        Name_Emp  Age  GT_5_yrs
# 0  Andy Simpson   34      True
# 2   Liza Brooke   23     False

# %%
Emp_Details.loc[[0,2],['Name_Emp','GT_5_yrs']]
# Out:
#        Name_Emp  GT_5_yrs
# 0  Andy Simpson      True
# 2   Liza Brooke     False

# %%
import os
os.getcwd()
# Out:
# '/home/labsuser/Datasets'

# %%
'''
Activity 

Sales_Region_wise = [23,3,12,9,0,"North Region","Central region","Great Lakes","West Region","East"]
Tasks:
1. Convert this to panda series
2. Find average of sales for all the regions
3. Find out region which as no sales
Note: You may need to separate this data into multiple series

'''

# %%
CaliforniaHousing = pd.read_csv("california_housing_test1.csv")

# %%
os.chdir('/home/labsuser/Datasets')

# %%
os.getcwd()
# Out:
# '/home/labsuser/Datasets'

# %%
CaliforniaHousing = pd.read_csv("california_housing_test1.csv")

# %%
Boston = pd.read_csv("boston.csv")
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
Boston.iloc[0:10,:]
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
Boston.iloc[0:10,0:3]
# Out:
#       crim    zn  indus
# 0  0.00632  18.0   2.31
# 1  0.02731   0.0   7.07
# 2  0.02729   0.0   7.07
# 3  0.03237   0.0   2.18
# 4  0.06905   0.0   2.18
# 5  0.02985   0.0   2.18
# 6  0.08829  12.5   7.87
# 7  0.14455  12.5   7.87
# 8  0.21124  12.5   7.87
# 9  0.17004  12.5   7.87

# %%
Boston.loc[:,"medv"]
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
Boston.loc[:,["medv","age"]]
# Out:
#      medv   age
# 0    24.0  65.2
# 1    21.6  78.9
# 2    34.7  61.1
# 3    33.4  45.8
# 4    36.2  54.2
# ..    ...   ...
# 501  22.4  69.1
# 502  20.6  76.7
# 503  23.9  91.0
# 504  22.0  89.3
# 505  11.9  80.8
#
# [506 rows x 2 columns]

# %%
Boston.loc[0:10,["medv","age"]]
# Out:
#     medv    age
# 0   24.0   65.2
# 1   21.6   78.9
# 2   34.7   61.1
# 3   33.4   45.8
# 4   36.2   54.2
# 5   28.7   58.7
# 6   22.9   66.6
# 7   27.1   96.1
# 8   16.5  100.0
# 9   18.9   85.9
# 10  15.0   94.3

# %%
Boston.iloc[0:10,[3,5]]
# Out:
#    chas     rm
# 0     0  6.575
# 1     0  6.421
# 2     0  7.185
# 3     0  6.998
# 4     0  7.147
# 5     0  6.430
# 6     0  6.012
# 7     0  6.172
# 8     0  5.631
# 9     0  6.004

# %%
Boston.iloc[[2,6,9],[3,5]]
# Out:
#    chas     rm
# 2     0  7.185
# 6     0  6.012
# 9     0  6.004

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# filter records
Boston[Boston['medv']>24]
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 407  11.95110   0.0  18.10     0  0.659  5.608  100.0  1.2852   24  666
# 409  14.43830   0.0  18.10     0  0.597  6.852  100.0  1.4655   24  666
# 473   4.64689   0.0  18.10     0  0.614  6.980   67.6  2.5329   24  666
# 482   5.73116   0.0  18.10     0  0.532  7.061   77.0  3.4106   24  666
# 494   0.27957   0.0   9.69     0  0.585  5.926   42.6  2.3817    6  391
#
#      ptratio   black  lstat  medv
# 2       17.8  392.83   4.03  34.7
# ...

# %%
# filter records
Boston[Boston['rad']==2]
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 56   0.02055  85.0   0.74     0  0.410  6.383  35.7  9.1876    2  313
# 88   0.05660   0.0   3.41     0  0.489  7.007  86.3  3.4217    2  270
# 89   0.05302   0.0   3.41     0  0.489  7.079  63.1  3.4145    2  270
# 90   0.04684   0.0   3.41     0  0.489  6.417  66.1  3.0923    2  270
# 91   0.03932   0.0   3.41     0  0.489  6.405  73.9  3.0921    2  270
# 95   0.12204   0.0   2.89     0  0.445  6.625  57.8  3.4952    2  276
# 96   0.11504   0.0   2.89     0  0.445  6.163  69.6  3.4952    2  276
# 97   0.12083   0.0   2.89     0  0.445  8.069  76.0  3.4952    2  276
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 99   0.06860   0.0   2.89     0  0.445  7.416  62.5  3.4952    2  276
# ...

# %%
# filter records
Boston[(Boston['rad']==2) & (Boston['medv']>24)]
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 56   0.02055  85.0   0.74     0  0.410  6.383  35.7  9.1876    2  313
# 89   0.05302   0.0   3.41     0  0.489  7.079  63.1  3.4145    2  270
# 95   0.12204   0.0   2.89     0  0.445  6.625  57.8  3.4952    2  276
# 97   0.12083   0.0   2.89     0  0.445  8.069  76.0  3.4952    2  276
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 99   0.06860   0.0   2.89     0  0.445  7.416  62.5  3.4952    2  276
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 201  0.03445  82.5   2.03     0  0.415  6.162  38.4  6.2700    2  348
# 202  0.02177  82.5   2.03     0  0.415  7.610  15.7  6.2700    2  348
#
#      ptratio   black  lstat  medv
# ...

# %%
'''
Task/Activity 
***************
1. Refer to dataset customer "Customer segment dataset.csv"
2. Data variables description
Balance - Average Balance on credit card
Purchase - Current month purchase bill
ONEOFF_PURCHASES - Cash payment of entire bill in same billing cycle
INSTALLMENTS_PURCHASES - Amount for which installments are availed
3. Import data
4. Filter records with ALL of conditions to be true
	1. balance >1000 
	2. CL >9000
	3. INSTALLMENTS_PURCHASES >3000
5. Filter first 50 records and variables mentioned in point 2 in separate data
6. Filter records with EITHER of conditions to be true
	1. balance >1000 
	2. CL >9000
	3. INSTALLMENTS_PURCHASES >3000
'''

# %%
import pandas as pd
customer_seg = pd.read_csv('Customer segment dataset.csv')

# %%
customer_seg
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# ...

# %%
customer_seg1 = customer_seg[(customer_seg.CREDIT_LIMIT>9000) & (customer_seg.BALANCE>1000) & (customer_seg.INSTALLMENTS_PURCHASES>3000)]
customer_seg1
# Out:
#      CUST_ID       BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 136   C10142   2494.868559           1.000000    5491.79           1390.50
# 138   C10144  19043.138560           1.000000   22009.92           9449.07
# 153   C10159  13673.079610           1.000000    9792.23           3959.81
# 220   C10229   9047.621884           1.000000   11188.62           6099.16
# 229   C10238   2723.369217           0.909091   10410.49           1158.84
# 263   C10274   7755.698607           1.000000    8533.54           4072.76
# 273   C10284   5131.319584           1.000000   32539.78          26547.43
# 376   C10388  11278.952430           1.000000    6855.59           2762.92
# 393   C10407  11209.370760           1.000000   11147.33           1137.40
# 423   C10438   6032.740391           1.000000    7553.48           2643.53
# 507   C10529   2643.343414           1.000000   26402.39          22257.39
# ...

# %%
customer_seg.loc[0:50, ['BALANCE', 'PURCHASES','INSTALLMENTS_PURCHASES']]
# Out:
#          BALANCE  PURCHASES  INSTALLMENTS_PURCHASES
# 0      40.900749      95.40                   95.40
# 1    3202.467416       0.00                    0.00
# 2    2495.148862     773.17                    0.00
# 3    1666.670542    1499.00                    0.00
# 4     817.714335      16.00                    0.00
# 5    1809.828751    1333.28                 1333.28
# 6     627.260806    7091.01                  688.38
# 7    1823.652743     436.20                  436.20
# 8    1014.926473     861.49                  200.00
# 9     152.225975    1281.60                    0.00
# 10   1293.124939     920.12                  920.12
# 11    630.794744    1492.18                    0.00
# 12   1516.928620    3217.99                  717.76
# 13    921.693369    2137.93                 1717.97
# 14   2772.772734       0.00                    0.00
# 15   6886.213231    1611.70                 1611.70
# 16   2072.074354       0.00                    0.00
# ...

# %%
customer_seg1 = customer_seg[(customer_seg.CREDIT_LIMIT>9000) | (customer_seg.BALANCE>1000) | (customer_seg.INSTALLMENTS_PURCHASES>3000)]
customer_seg1.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
#
#    INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# 1                    0.00             0.000000
# 2                    0.00             1.000000
# 3                    0.00             0.083333
# 5                 1333.28             0.666667
# 6                  688.38             1.000000
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CREDIT_LIMIT  TENURE
# 1                          0.000000        7000.0      12
# 2                          0.000000        7500.0      12
# 3                          0.000000        7500.0      12
# ...

# %%
customer_seg1.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   4508.000000        4508.000000   4508.000000       4508.000000
# mean    2827.197937           0.967542   1262.788077        779.813305
# std     2302.089392           0.110632   2796.089414       2155.549346
# min        0.488050           0.090909      0.000000          0.000000
# 25%     1307.582799           1.000000      0.000000          0.000000
# 50%     2029.367566           1.000000    348.235000         74.000000
# 75%     3676.109117           1.000000   1368.175000        762.915000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# count             4508.000000          4508.000000
# mean               483.193807             0.444473
# std               1171.102787             0.412624
# min                  0.000000             0.000000
# 25%                  0.000000             0.000000
# ...

# %%
print(customer_seg.shape)
print(customer_seg.size)
print(customer_seg.ndim)
# Out:
# (8950, 10)
# 89500
# 2

# %%
customer_seg.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# 0                    95.4             0.166667
# 1                     0.0             0.000000
# 2                     0.0             1.000000
# 3                     0.0             0.083333
# 4                     0.0             0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CREDIT_LIMIT  TENURE
# 0                          0.083333        1000.0      12
# 1                          0.000000        7000.0      12
# 2                          0.000000        7500.0      12
# ...

# %%
customer_seg.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# 0                   95.40             0.166667
# 1                    0.00             0.000000
# ...

# %%
customer_seg.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# 8945                  291.12             1.000000
# 8946                  300.00             1.000000
# 8947                  144.40             0.833333
# 8948                    0.00             0.000000
# 8949                    0.00             0.666667
#
#       PURCHASES_INSTALLMENTS_FREQUENCY  CREDIT_LIMIT  TENURE
# 8945                          0.833333        1000.0       6
# 8946                          0.833333        1000.0       6
# ...

# %%
customer_seg.tail(15)
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8935  C19176   183.817004           1.000000     465.90              0.00
# 8936  C19177   108.977282           1.000000     712.50              0.00
# 8937  C19178   163.001629           0.666667       0.00              0.00
# 8938  C19179    78.818407           0.500000       0.00              0.00
# 8939  C19180   728.352548           1.000000     734.40            734.40
# 8940  C19181   130.838554           1.000000     591.24              0.00
# 8941  C19182  5967.475270           0.833333     214.55              0.00
# 8942  C19183    40.829749           1.000000     113.28              0.00
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# ...

# %%
customer_seg
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# ...

# %%
## setting index names in data frames – 2 aspects – Retaining record/ overwriting the same data
customer_seg_new = customer_seg.set_index('CUST_ID')
customer_seg_new
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                    95.40             0.166667
# ...

# %%
customer_seg_new.loc[['C19190','C19189'],:]
# Out:
#             BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C19190   372.708075           0.666667    1093.25           1093.25
# C19189    13.457564           0.833333       0.00              0.00
#
#          INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# CUST_ID
# C19190                      0.0             0.666667
# C19189                      0.0             0.000000
#
#          PURCHASES_INSTALLMENTS_FREQUENCY  CREDIT_LIMIT  TENURE
# CUST_ID
# C19190                                0.0        1200.0       6
# C19189                                0.0         500.0       6

# %%
customer_seg_reinstated = customer_seg_new.reset_index()
customer_seg_reinstated
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# ...

# %%
# Concatenation
Emp1= pd.DataFrame({"Name":["John","Paul"],"Age":[34,32]})
Emp1
# Out:
#    Name  Age
# 0  John   34
# 1  Paul   32

# %%
Emp2= pd.DataFrame({"Name":["Alex","Lisa"],"Age":[23,21]})
Emp2
# Out:
#    Name  Age
# 0  Alex   23
# 1  Lisa   21

# %%
pd.concat([Emp1,Emp2],axis=0)
# Out:
#    Name  Age
# 0  John   34
# 1  Paul   32
# 0  Alex   23
# 1  Lisa   21

# %%
pd.concat([Emp1,Emp2],axis=0).reset_index(drop=True)
# Out:
#    Name  Age
# 0  John   34
# 1  Paul   32
# 2  Alex   23
# 3  Lisa   21

# %%
Emp1
# Out:
#    Name  Age
# 0  John   34
# 1  Paul   32

# %%
EmpDOJ = pd.DataFrame({'DOJ':["05-aug-2019","09-Nov-2016"]})
EmpDOJ
# Out:
#            DOJ
# 0  05-aug-2019
# 1  09-Nov-2016

# %%
pd.concat([Emp1,EmpDOJ],axis=1)
# Out:
#    Name  Age          DOJ
# 0  John   34  05-aug-2019
# 1  Paul   32  09-Nov-2016

# %%
# good to know below code
# pd.concat([pd.DataFrame(Emp1,index=[0,3]),EmpDOJ],axis=1)
# Out:
#    Name   Age          DOJ
# 0  John  34.0  05-aug-2019
# 1   NaN   NaN  09-Nov-2016
# 3   NaN   NaN          NaN

# %%
CaliforniaHousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27         3885             661
# 1    -118.30     34.26                  43         1510             310
# 2    -117.81     33.78                  27         3589             507
# 3    -118.36     33.82                  28           67              15
# 4    -119.67     36.33                  19         1241             244
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# 1         809         277         3.5990              176500
# 2        1484         495         5.7934              270500
# 3          49          11         6.1359              330000
# 4         850         237         2.9375               81700

# %%
# inserting a null record

import numpy as np
x = pd.DataFrame({'households':[10],'housing_median_age':[30],"latitude":[34],"longitude":[np.NaN],})
x
# Out:
#    households  housing_median_age  latitude  longitude
# 0          10                  30        34        NaN

# %%
CalWithNull = pd.concat([CaliforniaHousing,x],axis=0)
CalWithNull.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2996    -118.14     34.06                  27       5257.0          1082.0
# 2997    -119.70     36.30                  10        956.0           201.0
# 2998    -117.12     34.10                  40         96.0            14.0
# 2999    -119.63     34.42                  42       1765.0           263.0
# 0           NaN     34.00                  30          NaN             NaN
#
#       population  households  median_income  median_house_value
# 2996      3496.0        1036         3.3906            237200.0
# 2997       693.0         220         2.2895             62000.0
# 2998        46.0          14         3.2708            162500.0
# 2999       753.0         260         8.5608            500001.0
# 0            NaN          10            NaN                 NaN

# %%
CalWithNull.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
# 0          True     False               False         True            True
#
#       population  households  median_income  median_house_value
# ...

# %%
CalWithNull.median_income.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# 0        True
# Name: median_income, Length: 3001, dtype: bool

# %%
CalWithNull.median_income.isnull().sum()
# Out:
# 1

# %%
CalWithNull['total_rooms'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# 0        True
# Name: total_rooms, Length: 3001, dtype: bool

# %%
CalWithNull[CalWithNull['total_rooms'].isnull()]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        NaN      34.0                  30          NaN             NaN
#
#    population  households  median_income  median_house_value
# 0         NaN          10            NaN                 NaN

# %%
~CalWithNull['total_rooms'].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# 0       False
# Name: total_rooms, Length: 3001, dtype: bool

# %%
CalWithNull[~CalWithNull['total_rooms'].isnull()]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0           661.0
# 1       -118.30     34.26                  43       1510.0           310.0
# 2       -117.81     33.78                  27       3589.0           507.0
# 3       -118.36     33.82                  28         67.0            15.0
# 4       -119.67     36.33                  19       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23       1450.0           642.0
# 2996    -118.14     34.06                  27       5257.0          1082.0
# 2997    -119.70     36.30                  10        956.0           201.0
# 2998    -117.12     34.10                  40         96.0            14.0
# 2999    -119.63     34.42                  42       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# replacing nan with with 1000
CalWithNull.total_rooms = CalWithNull.total_rooms.fillna(1000)
CalWithNull
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0           661.0
# 1       -118.30     34.26                  43       1510.0           310.0
# 2       -117.81     33.78                  27       3589.0           507.0
# 3       -118.36     33.82                  28         67.0            15.0
# 4       -119.67     36.33                  19       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0          1082.0
# 2997    -119.70     36.30                  10        956.0           201.0
# 2998    -117.12     34.10                  40         96.0            14.0
# 2999    -119.63     34.42                  42       1765.0           263.0
# 0           NaN     34.00                  30       1000.0             NaN
#
#       population  households  median_income  median_house_value
# ...

# %%
# replacing nan with with 1000
CalWithNull.total_bedrooms = CalWithNull.total_bedrooms.fillna(CalWithNull.total_bedrooms.mean())
CalWithNull
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0      661.000000
# 1       -118.30     34.26                  43       1510.0      310.000000
# 2       -117.81     33.78                  27       3589.0      507.000000
# 3       -118.36     33.82                  28         67.0       15.000000
# 4       -119.67     36.33                  19       1241.0      244.000000
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0     1082.000000
# 2997    -119.70     36.30                  10        956.0      201.000000
# 2998    -117.12     34.10                  40         96.0       14.000000
# 2999    -119.63     34.42                  42       1765.0      263.000000
# 0           NaN     34.00                  30       1000.0      529.950667
#
#       population  households  median_income  median_house_value
# ...

# %%
# creating a new variable
CalWithNull['housing_median_age_new'] = CalWithNull.housing_median_age*1.2
CalWithNull
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0      661.000000
# 1       -118.30     34.26                  43       1510.0      310.000000
# 2       -117.81     33.78                  27       3589.0      507.000000
# 3       -118.36     33.82                  28         67.0       15.000000
# 4       -119.67     36.33                  19       1241.0      244.000000
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0     1082.000000
# 2997    -119.70     36.30                  10        956.0      201.000000
# 2998    -117.12     34.10                  40         96.0       14.000000
# 2999    -119.63     34.42                  42       1765.0      263.000000
# 0           NaN     34.00                  30       1000.0      529.950667
#
#       population  households  median_income  median_house_value  \
# ...

# %%
# group by to be covered

# %%
# writing a csv file
CalWithNull.to_csv('Temp.csv')

# %%
CalWithNull.longitude.describe()
# Out:
# count    3000.000000
# mean     -119.589200
# std         1.994936
# min      -124.180000
# 25%      -121.810000
# 50%      -118.485000
# 75%      -118.020000
# max      -114.490000
# Name: longitude, dtype: float64

# %%
CalWithNull_with_dups = pd.concat([CalWithNull,CalWithNull],axis=0)
print(len(CalWithNull))
print(len(CalWithNull_with_dups))
# Out:
# 3001
# 6002

# %%
CalWithNull_with_dups.drop_duplicates()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0      661.000000
# 1       -118.30     34.26                  43       1510.0      310.000000
# 2       -117.81     33.78                  27       3589.0      507.000000
# 3       -118.36     33.82                  28         67.0       15.000000
# 4       -119.67     36.33                  19       1241.0      244.000000
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0     1082.000000
# 2997    -119.70     36.30                  10        956.0      201.000000
# 2998    -117.12     34.10                  40         96.0       14.000000
# 2999    -119.63     34.42                  42       1765.0      263.000000
# 0           NaN     34.00                  30       1000.0      529.950667
#
#       population  households  median_income  median_house_value  \
# ...

# %%
CalWithNull_with_dups.drop('median_house_value',axis=1)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0      661.000000
# 1       -118.30     34.26                  43       1510.0      310.000000
# 2       -117.81     33.78                  27       3589.0      507.000000
# 3       -118.36     33.82                  28         67.0       15.000000
# 4       -119.67     36.33                  19       1241.0      244.000000
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0     1082.000000
# 2997    -119.70     36.30                  10        956.0      201.000000
# 2998    -117.12     34.10                  40         96.0       14.000000
# 2999    -119.63     34.42                  42       1765.0      263.000000
# 0           NaN     34.00                  30       1000.0      529.950667
#
#       population  households  median_income  housing_median_age_new
# ...

# %%
CalWithNull_with_dups.iloc[:,[0,1,2,3,4,5,6,7,9]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27       3885.0      661.000000
# 1       -118.30     34.26                  43       1510.0      310.000000
# 2       -117.81     33.78                  27       3589.0      507.000000
# 3       -118.36     33.82                  28         67.0       15.000000
# 4       -119.67     36.33                  19       1241.0      244.000000
# ...         ...       ...                 ...          ...             ...
# 2996    -118.14     34.06                  27       5257.0     1082.000000
# 2997    -119.70     36.30                  10        956.0      201.000000
# 2998    -117.12     34.10                  40         96.0       14.000000
# 2999    -119.63     34.42                  42       1765.0      263.000000
# 0           NaN     34.00                  30       1000.0      529.950667
#
#       population  households  median_income  housing_median_age_new
# ...
