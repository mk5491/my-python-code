# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=40,
            shear_range=0.55,
            zoom_range= 0.22,
            horizontal_flip= True,
            brightness_range=(0.1,0.2),
            vertical_flip=True)

# %%
img = load_img('chair2.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# %%
import os
os.getcwd()
# Out:
# '/home/manoj/Documents/Class_6_30_08_2020'

# %%
dir_1 = r'/home/manoj/Documents/Class_6_30_08_2020'
i=0
for batch in datagen.flow(x, batch_size=1,
                         save_to_dir= dir_1,
                         save_prefix='image', save_format ='jpeg'):
    i += 1
    if i > 5:
        break

# %% [markdown]
# Save Images

# %% [markdown]
# ![image_0_1856.jpeg](attachment:image_0_1856.jpeg) /t ![image_0_602.jpeg](attachment:image_0_602.jpeg)

# %% [markdown]
# ![image_0_602.jpeg](attachment:image_0_602.jpeg)

# %% [markdown]
# ![image_0_5775.jpeg](attachment:image_0_5775.jpeg)

# %% [markdown]
# ![image_0_3575.jpeg](attachment:image_0_3575.jpeg)

# %% [markdown]
# ![image_0_3434.jpeg](attachment:image_0_3434.jpeg)

# %% [markdown]
# ![image_0_3533.jpeg](attachment:image_0_3533.jpeg)
