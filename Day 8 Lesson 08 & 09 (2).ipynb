# %%
# logistic regression
'''
Lesson 08
Agenda
1.  Logistic regression 
1.	ML Algorithm - KNN Algorithm
2.	Clustering - K means clustering
3.	PCA –

Lesson 09 - NLP
--
'''

# %%
import os
os.getcwd()
# Out:
# '/home/labsuser/2020.03.21 Batch'

# %%
import pandas as pd
CancerData  = pd.read_csv("/home/labsuser/Datasets/Cancer.csv")

# %%
CancerData
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
x = CancerData.iloc[:,2:]
y = CancerData['diagnosis']

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
Model_Cancer = lm.fit(x,y)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
PredictedValues = Model_Cancer.predict(x)
PredictedValues = pd.DataFrame(PredictedValues,columns=['Diagnosis_predicted'])
Predicted_table = pd.concat([x,y,PredictedValues],axis=1)

# %%
Predicted_table
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
pd.crosstab(Predicted_table.diagnosis,Predicted_table.Diagnosis_predicted)
# Out:
# Diagnosis_predicted    B    M
# diagnosis
# B                    346   11
# M                     19  193

# %%
(346+193)/569
# Out:
# 0.9472759226713533

# %%
from sklearn import metrics
metrics.accuracy_score(Predicted_table.diagnosis,Predicted_table.Diagnosis_predicted)
# Out:
# 0.9472759226713533

# %%
Model_Cancer.intercept_
# Out:
# array([-0.17556275])

# %%
print(x.columns)
Model_Cancer.coef_
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')
# array([[-0.94240462, -0.45580294, -0.28065785,  0.01639514,  0.03501284,
#          0.16503045,  0.23107064,  0.09731311,  0.04849993,  0.00967266,
#         -0.04091329, -0.37159302, -0.14373594,  0.10951994,  0.00316779,
#          0.03548944,  0.04942125,  0.01267271,  0.01170905,  0.00329475,
# ...

# %%
# divide data into training and test data - Home work

# %%
#################### KNN ####################
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)
knn_model = classifier.fit(x, y)

# %%
PredictedValues = knn_model.predict(x)
PredictedValues = pd.DataFrame(PredictedValues,columns=['Diagnosis_predicted'])
Predicted_table = pd.concat([x,y,PredictedValues],axis=1)
metrics.accuracy_score(Predicted_table.diagnosis,Predicted_table.Diagnosis_predicted)
# Out:
# 0.9560632688927944

# %%
#################### KNN ####################
for i in range(3,10):
    classifier = KNeighborsClassifier(n_neighbors=i)
    knn_model = classifier.fit(x, y)
    PredictedValues = knn_model.predict(x)
    PredictedValues = pd.DataFrame(PredictedValues,columns=['Diagnosis_predicted'])
    Predicted_table = pd.concat([x,y,PredictedValues],axis=1)
    Acc_scor = metrics.accuracy_score(Predicted_table.diagnosis,Predicted_table.Diagnosis_predicted)
    print ("Accuracy Rate--> " + str(Acc_scor)+" KNN # " + str(i))
# Out:
# Accuracy Rate--> 0.9560632688927944 KNN # 3
# Accuracy Rate--> 0.9490333919156415 KNN # 4
# Accuracy Rate--> 0.9472759226713533 KNN # 5
# Accuracy Rate--> 0.9472759226713533 KNN # 6
# Accuracy Rate--> 0.9437609841827768 KNN # 7
# Accuracy Rate--> 0.9402460456942003 KNN # 8
# Accuracy Rate--> 0.9420035149384886 KNN # 9

# %%
classifier = KNeighborsClassifier(n_neighbors=3)
knn_model = classifier.fit(x, y)
PredictedValues = knn_model.predict(x)
PredictedValues = pd.DataFrame(PredictedValues,columns=['Diagnosis_predicted'])
Predicted_table = pd.concat([x,y,PredictedValues],axis=1)
metrics.accuracy_score(Predicted_table.diagnosis,Predicted_table.Diagnosis_predicted)
# Out:
# 0.9560632688927944

# %%
# step 1 - importing data
Movies = pd.read_csv("/home/labsuser/Datasets/movie_metadata.csv") 
Movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
MoviesSubset = Movies.iloc[:,4:6]
MoviesSubset=MoviesSubset.dropna()
MoviesSubset
# Out:
#       director_facebook_likes  actor_3_facebook_likes
# 0                         0.0                   855.0
# 1                       563.0                  1000.0
# 2                         0.0                   161.0
# 3                     22000.0                 23000.0
# 5                       475.0                   530.0
# ...                       ...                     ...
# 5037                      0.0                   133.0
# 5038                      2.0                   318.0
# 5040                      0.0                     0.0
# 5041                      0.0                   489.0
# 5042                     16.0                    16.0
#
# [4919 rows x 2 columns]

# %%
# Step 3 - Running kmeans cluster
from sklearn.cluster import KMeans 
kmeansfunction = KMeans(n_clusters=5)
Movies_kmeans = kmeansfunction.fit(MoviesSubset)
ClNum = Movies_kmeans.labels_ # gives cluster numeber for each observation in original data

# %%
# Step 4 - Appending cluster number to original data
# converting to data frame with a column name
ClNum = pd.DataFrame(Movies_kmeans.labels_, columns=['ClusterNumber'])
ClNum
# gives unique number of clusters. Cluster number is starting 0
np.unique(ClNum['ClusterNumber'])
# concatenating clusters variable with Movie data
Final_Movies = pd.concat([Movies,ClNum],axis=1)

# %%
np.unique(ClNum['ClusterNumber'])
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
Final_Movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
Final_Movies.groupby('ClusterNumber')['director_facebook_likes','actor_3_facebook_likes'].agg({'director_facebook_likes':['count','mean'],'actor_3_facebook_likes':['mean']})
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               director_facebook_likes              actor_3_facebook_likes
#                                 count         mean                   mean
# ClusterNumber
# 0.0                              4551   689.405845             636.245792
# 1.0                                11  5525.272727            3397.363636
# 2.0                                87   830.701149            1063.000000
# 3.0                                68   605.338235             680.985294
# 4.0                                99   503.212121             973.156863

# %%
Movies_kmeans.cluster_centers_
# Out:
# array([[  153.94452806,   424.19264674],
#        [17545.45454545, 14545.45454545],
#        [  210.77011494, 11126.43678161],
#        [17544.11764706,   598.77941176],
#        [12441.17647059,   604.34313725]])

# %%
############ Lesson 09 - NLP ############
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
print(ps.stem("runs"))
print(ps.stem("betterment"))
print(ps.stem("wolves"))

# Lemmatization
# https://www.geeksforgeeks.org/python-lemmatization-with-nltk/
# Out:
# run
# better
# wolv

# %%
# Lemmatization
import nltk
# To be executed only once
nltk.download('wordnet') 
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 
print(lemmatizer.lemmatize("wolves"))
print(lemmatizer.lemmatize("resumes", pos="n")) 
print(lemmatizer.lemmatize("better", pos="a")) # will show good instead of better i.e. root word
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1076)>
# wolf
# resume
# good

# %%
print(lemmatizer.lemmatize("better", pos="a")) # POS will be good
print(lemmatizer.lemmatize("good", pos="a"))
# Out:
# good
# good

# %%
####################################### Spam Detector Model - Case Study #######################################
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('/home/labsuser/Datasets/spam.csv', encoding='ISO-8859-1')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-0805ad99b520> in <module>
# ----> 1 df = pd.read_csv('/home/labsuser/Datasets/spam.csv', encoding='ISO-8859-1')
#       2 df
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
# drop unnecessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# rename columns to something better
df.columns = ['labels', 'data']

# create binary labels
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1})
Y = df['b_labels'].values

# %%
count_vectorizer = CountVectorizer(decode_error='ignore')
X = count_vectorizer.fit_transform(df['data'])

# %%
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fa0134f942c4> in <module>
# ----> 1 print(X)
#
# NameError: name 'X' is not defined

# %%
# split up the data
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2)

# create the model, train it, print scores
model = MultinomialNB()
model.fit(Xtrain, Ytrain)

# %%
# Predicting on test data
y_pred = model.predict(Xtest)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, y_pred)
print(cm)

# %%
from sklearn import metrics
metrics.accuracy_score(Ytest, y_pred)

# %%
# Test with some new data 
comment = "URGENT Free membership"
data = [comment]
vect = count_vectorizer.transform(data).toarray()
my_prediction = model.predict(vect)

if(my_prediction == 0):
     print("Ham")
if(my_prediction == 1):
     print("Spam")

# %%
#word cloud
# !pip install wordcloud
from wordcloud import WordCloud
# visualize the data
def visualize(label):
  words = ''
  for msg in df[df['labels'] == label]['data']:
    msg = msg.lower()
    words += msg + ' '
  wordcloud = WordCloud(width=600, height=400).generate(words)
  plt.imshow(wordcloud)
  plt.axis('off')
  plt.show()

visualize('spam') # word cloud for spam messages
visualize('ham') # word cloud for ham messages

# %%
# sentiment analysis
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

a = 'This was a good movie'
print(sid.polarity_scores(a))

a = 'This was the best, most awesome movie EVER MADE!!!'
print(sid.polarity_scores(a))

a = 'This was the worst film to ever disgrace the screen.'
print(sid.polarity_scores(a))
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.8877}
# {'neg': 0.477, 'neu': 0.523, 'pos': 0.0, 'compound': -0.8074}
# [nltk_data] Error loading vader_lexicon: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1076)>
